# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC, SVR
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv('second_hand_car_price.csv')
data
# Out:
#        id  brand   model                         title    price  \
# 0       1  honda  accord    2010 Honda Accord VTi Auto  13990.0
# 1       2  honda  accord  2007 Honda Accord VTi-L Auto   5900.0
# 2       3  honda  accord  2008 Honda Accord VTi-L Auto   8750.0
# 3       4  honda  accord    2013 Honda Accord V6L Auto  22900.0
# 4       5  honda  accord  2013 Honda Accord VTi-L Auto  18888.0
# ..    ...    ...     ...                           ...      ...
# 995   996  honda    city      2012 Honda City VTi Auto  13888.0
# 996   997  honda    city    2013 Honda City VTi Manual   8999.0
# 997   998  honda    city    2009 Honda City VTi Manual   7990.0
# 998   999  honda    city      2018 Honda City VTi Auto  18888.0
# 999  1000  honda    city    2018 Honda City VTi Manual  15962.0
#
#                 discount  odometres   body transmission            engine  \
# 0    Excl. Govt. Charges      54830  Sedan    Automatic  4cyl 2.4L Petrol
# ...

# %%
data.isna().sum()
# Out:
# id              0
# brand           0
# model           0
# title           0
# price           0
# discount        0
# odometres       0
# body            0
# transmission    0
# engine          0
# state           0
# seller          0
# year            0
# dtype: int64

# %%
data.dtypes
# Out:
# id                int64
# brand            object
# model            object
# title            object
# price           float64
# discount         object
# odometres         int64
# body             object
# transmission     object
# engine           object
# state            object
# seller           object
# year              int64
# dtype: object

# %%
data=data.drop(['id'],axis=1)
data
# Out:
#      brand   model                         title    price  \
# 0    honda  accord    2010 Honda Accord VTi Auto  13990.0
# 1    honda  accord  2007 Honda Accord VTi-L Auto   5900.0
# 2    honda  accord  2008 Honda Accord VTi-L Auto   8750.0
# 3    honda  accord    2013 Honda Accord V6L Auto  22900.0
# 4    honda  accord  2013 Honda Accord VTi-L Auto  18888.0
# ..     ...     ...                           ...      ...
# 995  honda    city      2012 Honda City VTi Auto  13888.0
# 996  honda    city    2013 Honda City VTi Manual   8999.0
# 997  honda    city    2009 Honda City VTi Manual   7990.0
# 998  honda    city      2018 Honda City VTi Auto  18888.0
# 999  honda    city    2018 Honda City VTi Manual  15962.0
#
#                 discount  odometres   body transmission            engine  \
# 0    Excl. Govt. Charges      54830  Sedan    Automatic  4cyl 2.4L Petrol
# 1                   None     180000  Sedan    Automatic  4cyl 2.4L Petrol
# ...

# %%
data=data.head(800)
data
# Out:
#      brand       model                               title    price  \
# 0    honda      accord          2010 Honda Accord VTi Auto  13990.0
# 1    honda      accord        2007 Honda Accord VTi-L Auto   5900.0
# 2    honda      accord        2008 Honda Accord VTi-L Auto   8750.0
# 3    honda      accord          2013 Honda Accord V6L Auto  22900.0
# 4    honda      accord        2013 Honda Accord VTi-L Auto  18888.0
# ..     ...         ...                                 ...      ...
# 795  honda  accordeuro       2012 Honda Accord Euro Manual  13000.0
# 796  honda  accordeuro  2007 Honda Accord Euro Luxury Auto  20000.0
# 797  honda  accordeuro         2008 Honda Accord Euro Auto   7999.0
# 798  honda  accordeuro         2004 Honda Accord Euro Auto   7550.0
# 799  honda  accordeuro  2007 Honda Accord Euro Luxury Auto   6500.0
#
#                 discount  odometres   body transmission            engine  \
# 0    Excl. Govt. Charges      54830  Sedan    Automatic  4cyl 2.4L Petrol
# ...

# %%
brand=LabelEncoder()
model=LabelEncoder()
title=LabelEncoder()
discount=LabelEncoder()
body=LabelEncoder()
transmission=LabelEncoder()
engine=LabelEncoder()
state=LabelEncoder()
seller=LabelEncoder()

# %%
data['brand']=brand.fit_transform(data['brand'])
data['model']=model.fit_transform(data['model'])
data['title']=title.fit_transform(data['title'])
data['discount']=discount.fit_transform(data['discount'])
data['body']=body.fit_transform(data['body'])
data['transmission']=transmission.fit_transform(data['transmission'])
data['engine']=engine.fit_transform(data['engine'])
data['state']=state.fit_transform(data['state'])
data['seller']=seller.fit_transform(data['seller'])
data
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8188\3858956460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['brand']=brand.fit_transform(data['brand'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8188\3858956460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['model']=model.fit_transform(data['model'])
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8188\3858956460.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=25)

# %%
x_train.shape,y_train.shape
# Out:
# ((640, 11), (640,))

# %%
x_test.shape,y_test.shape
# Out:
# ((160, 11), (160,))

# %%
model=RandomForestRegressor(n_estimators=500,random_state=25)
model.fit(x_train,y_train) 
model.score(x_train,y_train)
# Out:
# 0.9883827366644926

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([10064.368, 10659.3  ,  6045.55 , 12422.322,  8759.48 ,  8111.62 ,
#         5194.228,  3544.594,  7237.06 , 10731.31 ,  8335.57 , 10156.748,
#         7067.052, 10914.38 , 26409.454, 18118.964,  3807.876, 11238.212,
#         6612.8  , 13502.206, 15692.8  , 52252.304, 11636.75 ,  8278.264,
#        14796.126, 10065.96 , 10915.166,  4947.178, 16263.318, 16865.454,
#        10456.504,  4428.118, 13141.764,  8817.452, 21980.828,  7839.798,
#         4901.564, 13487.578,  6113.22 ,  2313.194,  8182.528, 10542.01 ,
#         5362.584,  1350.686, 13864.546,  5526.302, 11366.186, 15720.776,
#         7593.256,  8722.286,  6477.354, 10825.356,  7327.706, 11620.126,
#        10524.388,  6019.592,  9436.252,  6872.204, 14881.708,  5954.068,
#         7771.132, 44440.062,  4317.728,  4964.96 , 12907.09 , 21411.698,
#        12191.57 , 15981.17 ,  6765.524,  6269.344,  8857.766, 10906.994,
#        10680.37 , 12690.092,  7735.42 ,  7311.756,  9203.824,  7546.812,
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.8958072970207354

# %%
model.score(x_test,y_test)

# %%
scores=[]
models=['svr','random_forest', 'decision_tree']
for model_name in models:  
    mp=model_params[model_name] 
    gds=GridSearchCV(mp['model'],mp['params'],cv=4,return_train_score=True)
    gds.fit(x_scaled,y)
    scores.append({'model':model_name,'best_score':gds.best_score_,'best_params':gds.best_params_})

# %%
scores
# Out:
# [{'model': 'svr',
#   'best_score': 0.0678298394806989,
#   'best_params': {'C': 20, 'kernel': 'linear'}},
#  {'model': 'random_forest',
#   'best_score': 0.8170776677731706,
#   'best_params': {'n_estimators': 15}},
#  {'model': 'decision_tree',
#   'best_score': 0.7730130940640629,
#   'best_params': {'max_depth': 6}}]

# %%
df=pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#            model  best_score                    best_params
# 0            svr    0.067830  {'C': 20, 'kernel': 'linear'}
# 1  random_forest    0.817078           {'n_estimators': 15}
# 2  decision_tree    0.773013               {'max_depth': 6}

# %%
model.predict([[]])
